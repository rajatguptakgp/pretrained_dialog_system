# %%
#takes training losses and validation losses as input
import matplotlib.pyplot as plt

df = pd.read_csv('plot2.csv')
df.head()
# Out:
#    Train Loss  Val Loss  Training PPL  Validation PPL
# 0       3.670     5.527        39.245         251.294
# 1       3.479     5.527        32.423         251.497
# 2       3.287     5.619        26.760         275.687
# 3       3.161     5.647        23.591         283.417
# 4       3.245     5.597        25.662         269.569

# %%
def return_plot(df,label):
    X=df.index+1
    Y=df[label].values
    
    plt.title(f'{label}')
    plt.xlabel('Epochs')
    plt.ylabel('Values')

    plt.plot(X,Y,c='k',linestyle='--',marker='o')
    return plt

fig=plt.figure(figsize=(15, 5), dpi= 80, facecolor='w', edgecolor='k')

ax = plt.subplot(121)
plt1 = return_plot(df,'Train Loss')

ax = plt.subplot(122)
plt2 = return_plot(df,'Val Loss')

plt.show()

fig=plt.figure(figsize=(15, 5), dpi= 80, facecolor='w', edgecolor='k')

ax = plt.subplot(121)
plt1 = return_plot(df,'Training PPL')

ax = plt.subplot(122)
plt2 = return_plot(df,'Validation PPL')

plt.show()
